# %% [markdown]
# <em><pre>
# 	<h3 style="position: relative; text-align: center;">Обробка та аналіз бмд Грініх К.А група БС-82</h3>
# 	</pre></em>

# %% [markdown]
# <em><pre>
# 	<h4 style="position: relative; text-align: center;">Введення данних вручну</h3>
# 	</pre></em>

# %%
import pandas as p

# %%
new_df = p.DataFrame(
{
"№": [1, 2, 3, 4, 5],
"Name":['Kate', 'Misha', 'Yana', 'Sasha', 'Lyna'],
"Surname":['Grinikh', 'Petrov', 'Ivanova', 'Sydorov', 'Kiseleva'],
"University":['KPI', 'KNU', 'KPI', 'NAU', 'KPI'],
"Group":['BS-82', 'TL-62', 'BS-81', 'TD-83', 'OS-73'],
"Mark": [10, 8, 9.5, 2.8, 6]
})

new_df
# Out:
#    №   Name   Surname University  Group  Mark
# 0  1   Kate   Grinikh        KPI  BS-82  10.0
# 1  2  Misha    Petrov        KNU  TL-62   8.0
# 2  3   Yana   Ivanova        KPI  BS-81   9.5
# 3  4  Sasha   Sydorov        NAU  TD-83   2.8
# 4  5   Lyna  Kiseleva        KPI  OS-73   6.0

# %% [markdown]
# <em><pre>
# 	<h4 style="position: relative; text-align: center;">Завантаження данних з CSV файлу</h3>
# 	</pre></em>

# %%
path = r"C:\Users\Anna\Downloads\avocado.csv\avocado.csv"
data=p.read_csv(path, encoding="utf-8")

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# <em><pre>
# 	<h4 style="position: relative; text-align: center;">2.2 Завантаження файлу з директорії</h3>
# 	</pre></em>

# %%
import os

print("The directory we are wirking in is: {0}".format(os.getcwd()))
# Out:
# The directory we are wirking in is: C:\Users\Anna

# %%
data=p.read_csv('avocado.csv')

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# <em><pre>
# 	<h4 style="position: relative; text-align: center;">Відображення завантажених данних</h3>
# 	</pre></em>

# %%
data
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %% [markdown]
# <em><pre>
# 	<h4 style="position: relative; text-align: center;">Базова статистика про завантажені дані</h3>
# 	</pre></em>

# %%
data.shape
# Out:
# (18249, 14)

# %%
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
data.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
data.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# <em><pre>
# 	<h4 style="position: relative; text-align: center;">Використання describe</h3>
# 	</pre></em>

# %%
data['Total Volume'].describe()
# Out:
# count    1.824900e+04
# mean     8.506440e+05
# std      3.453545e+06
# min      8.456000e+01
# 25%      1.083858e+04
# 50%      1.073768e+05
# 75%      4.329623e+05
# max      6.250565e+07
# Name: Total Volume, dtype: float64

# %%
data['AveragePrice'].describe()
# Out:
# count    18249.000000
# mean         1.405978
# std          0.402677
# min          0.440000
# 25%          1.100000
# 50%          1.370000
# 75%          1.660000
# max          3.250000
# Name: AveragePrice, dtype: float64

# %%
cut_data=data.iloc[0:10, :]
cut_data
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5           5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6           6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7           7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8           8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9           9  2015-10-25          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# ...

# %%
new_data=[1,1,2,2,1,2,1,2,2,1]
cut_data.insert(1,"Group", new_data)
cut_data
# Out:
#    Unnamed: 0  Group        Date  AveragePrice  Total Volume     4046  \
# 0           0      1  2015-12-27          1.33      64236.62  1036.74
# 1           1      1  2015-12-20          1.35      54876.98   674.28
# 2           2      2  2015-12-13          0.93     118220.22   794.70
# 3           3      2  2015-12-06          1.08      78992.15  1132.00
# 4           4      1  2015-11-29          1.28      51039.60   941.48
# 5           5      2  2015-11-22          1.26      55979.78  1184.27
# 6           6      1  2015-11-15          0.99      83453.76  1368.92
# 7           7      2  2015-11-08          0.98     109428.33   703.75
# 8           8      2  2015-11-01          1.02      99811.42  1022.15
# 9           9      1  2015-10-25          1.07      74338.76   842.40
#
#         4225    4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 0   54454.85   48.16     8696.87     8603.62       93.25          0.0
# ...

# %% [markdown]
# <em><pre>
# 	<h4 style="position: relative; text-align: center;">Виведення статистики з розподіленням на групи</h3>
# 	</pre></em>

# %%
cut_data.groupby('Group').describe()
# Out:
#       Unnamed: 0                                         AveragePrice         \
#            count mean       std  min  25%  50%  75%  max        count   mean
# Group
# 1            5.0  4.0  3.674235  0.0  1.0  4.0  6.0  9.0          5.0  1.204
# 2            5.0  5.0  2.549510  2.0  3.0  5.0  7.0  8.0          5.0  1.054
#
#        ... XLarge Bags       year                                       \
#        ...         75%  max count    mean  std     min     25%     50%
# Group  ...
# 1      ...         0.0  0.0   5.0  2015.0  0.0  2015.0  2015.0  2015.0
# 2      ...         0.0  0.0   5.0  2015.0  0.0  2015.0  2015.0  2015.0
#
#
#           75%     max
# Group
# 1      2015.0  2015.0
# 2      2015.0  2015.0
#
# [2 rows x 88 columns]

# %%
cut_data.to_csv("output.csv", encoding='utf-8')

# %%
data.to_csv("full_output.csv", encoding='utf-8')
