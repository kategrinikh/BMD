# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x=np.linspace(0,5,11) #11 значень від 0 до 5
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
#functional method
plt.plot(x,y) 
plt.xlabel('xlabel')
plt.ylabel('ylabel')
plt.title('title')
# Out:
# Text(0.5, 1.0, 'title')

# %%
#create multiply plots
plt.subplot(1, 2, 1) #1 рядок, 2 стовпчики, 1й графік
plt.plot(x, y, 'r')

plt.subplot(1, 2, 2) #1 рядок, 2 стовпчики, 2й графік
plt.plot(x, y, 'g')

# %%
#oo method
fig=plt.figure()

axes=fig.add_axes([0, 0, 1, 1])
axes.plot(x, y)
axes.set_xlabel('X label')
axes.set_ylabel('Y label')
axes.set_title('tittle')
# Out:
# Text(0.5, 1.0, 'tittle')

# %%
fig=plt.figure()

axes1=fig.add_axes([0, 0, 1, 1])
axes2=fig.add_axes([0.1, 0.5, 0.4, 0.3])

axes1.plot(x, y, 'r')
axes1.set_xlabel('X label')
axes1.set_ylabel('Y label')
axes1.set_title('tittle')

axes2.plot(y, x, 'g')
axes2.set_xlabel('Y label')
axes2.set_ylabel('X label')
axes2.set_title('tittle')
# Out:
# Text(0.5, 1.0, 'tittle')

# %%
#ініціалізація графіка як об'єкта
fig, axes=plt.subplots()

axes.plot(y, x, 'b')
axes.set_xlabel('Y label')
axes.set_ylabel('X label')
axes.set_title('tittle')
# Out:
# Text(0.5, 1.0, 'tittle')

# %%
fig, axes=plt.subplots(nrows=2, ncols=3)

axes[0,0].plot(x,y,'g')
axes[0,1].plot(y,x, 'b')
axes[0,2].plot(x,y, 'y')

axes[1,0].plot(x,y,'g')
axes[1,1].plot(y,x, 'b')
axes[1,2].plot(x,y,'y')

# %%
fig, axes=plt.subplots(nrows=4, ncols=4)

# %%
plt.tight_layout()

# %%
fig=plt.figure()

ax=fig.add_axes([0,0,1,1])
ax.plot(x, x**2, label="x**2")
ax.plot(x, x**3, label="x**3")
ax.legend()

# %%
fig=plt.figure(figsize=(8,4), dpi=100)

# %%
#matlab style line color & style
fig, ax=plt.subplots()
ax.plot(x, x**2, color='y')
ax.plot(x, x**3, color='g')

# %%
#matlab style ширина линии
fig, ax=plt.subplots()
ax.plot(x, x**2, lw=2, ls='--' )

# %%
#matlab style тип, размер и цвет маркеров
fig, ax=plt.subplots()
ax.plot(x, x**2, marker='^', markersize=10, markerfacecolor='b')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-bc21ed5f55db> in <module>
#       2 fig, ax=plt.subplots()
#       3 ax.plot(x, x**2, marker='^', markersize=10, markerfacecolor='b')
# ----> 4 fig.savefig(lalala.png)
#
# NameError: name 'lalala' is not defined

# %%
fig.savefig("lalala.png")

# %%
plt.scatter(x,y)

# %%
from random import sample
data=sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([ 9., 11., 10.,  7., 10., 10.,  9., 15.,  8., 11.]),
#  array([  1. , 100.8, 200.6, 300.4, 400.2, 500. , 599.8, 699.6, 799.4,
#         899.2, 999. ]),
#  <a list of 10 Patch objects>)

# %%
data=[np.random.normal(0, std, 100) for std in range(1,4)]

plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x4e8ff17708>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x4e8ff1a948>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x4e8ff170c8>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x4e8ff218c8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x4e8ff21f88>,
# ...
#  'means': []}
